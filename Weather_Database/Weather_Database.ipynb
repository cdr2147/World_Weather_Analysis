# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nanortalik
# Processing Record 2 of Set 1 | kavaratti
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | raudeberg
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | manuk mangkaw
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | sechura
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | ostrovnoy
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | kilindoni
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | kalmunai
# Processing Record 17 of Set 1 | sabha
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | providencia
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | pucara
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | porto novo
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | yellapur
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | vila do maio
# Processing Record 31 of Set 1 | nokaneng
# Processing Record 32 of Set 1 | two hills
# Processing Record 33 of Set 1 | otjimbingwe
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | togur
# Processing Record 36 of Set 1 | hirara
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | vanimo
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | awjilah
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | comrat
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | beloha
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | zhigansk
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | kuryk
# Processing Record 4 of Set 2 | omboue
# Processing Record 5 of Set 2 | rafraf
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | buraydah
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 2 | hambantota
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | rikitea
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | nizhniy tsasuchey
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | grindavik
# Processing Record 20 of Set 2 | agucadoura
# Processing Record 21 of Set 2 | opuwo
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | atar
# Processing Record 24 of Set 2 | poum
# Processing Record 25 of Set 2 | tautira
# Processing Record 26 of Set 2 | fayaoue
# Processing Record 27 of Set 2 | san quintin
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | wenling
# Processing Record 30 of Set 2 | samarai
# Processing Record 31 of Set 2 | ahipara
# Processing Record 32 of Set 2 | la baule-escoublac
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | pilar
# Processing Record 35 of Set 2 | byron bay
# Processing Record 36 of Set 2 | qaqortoq
# Processing Record 37 of Set 2 | ario
# City not found. Skipping...
# Processing Record 38 of Set 2 | tiarei
# Processing Record 39 of Set 2 | ulaangom
# Processing Record 40 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 2 | sibolga
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | maracacume
# Processing Record 44 of Set 2 | abashiri
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | nioro
# Processing Record 48 of Set 2 | plouzane
# Processing Record 49 of Set 2 | katangli
# Processing Record 50 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 1 of Set 3 | san cristobal
# Processing Record 2 of Set 3 | guayaramerin
# Processing Record 3 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 3 | halifax
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | northam
# Processing Record 7 of Set 3 | tukrah
# Processing Record 8 of Set 3 | lakatoro
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 11 of Set 3 | minab
# Processing Record 12 of Set 3 | college
# Processing Record 13 of Set 3 | kampot
# Processing Record 14 of Set 3 | deputatskiy
# Processing Record 15 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | snasa
# Processing Record 20 of Set 3 | popondetta
# Processing Record 21 of Set 3 | itaueira
# Processing Record 22 of Set 3 | arenapolis
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | linhares
# Processing Record 25 of Set 3 | manaquiri
# Processing Record 26 of Set 3 | praia
# Processing Record 27 of Set 3 | rio grande
# Processing Record 28 of Set 3 | anchorage
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | klichka
# Processing Record 31 of Set 3 | krasni okny
# Processing Record 32 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 3 | sioux lookout
# Processing Record 34 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | adrar
# Processing Record 39 of Set 3 | lokosovo
# Processing Record 40 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 3 | tuatapere
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | hualmay
# Processing Record 44 of Set 3 | anadyr
# Processing Record 45 of Set 3 | chapais
# Processing Record 46 of Set 3 | meulaboh
# Processing Record 47 of Set 3 | sonoita
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | helena
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 4 | shakawe
# Processing Record 6 of Set 4 | portland
# Processing Record 7 of Set 4 | quibdo
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | cortez
# Processing Record 10 of Set 4 | petrozavodsk
# Processing Record 11 of Set 4 | hainburg
# Processing Record 12 of Set 4 | teya
# Processing Record 13 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 4 | saint anthony
# Processing Record 15 of Set 4 | cape town
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | grand gaube
# Processing Record 18 of Set 4 | kaili
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | oistins
# Processing Record 21 of Set 4 | atherton
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | ginda
# Processing Record 25 of Set 4 | natal
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | umkomaas
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | brzeg dolny
# Processing Record 31 of Set 4 | yulara
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | namibe
# Processing Record 34 of Set 4 | sovetskiy
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | batagay-alyta
# Processing Record 38 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | viransehir
# Processing Record 42 of Set 4 | saint george
# Processing Record 43 of Set 4 | biryusinsk
# Processing Record 44 of Set 4 | imperia
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | filingue
# Processing Record 47 of Set 4 | kumluca
# Processing Record 48 of Set 4 | manavalakurichi
# Processing Record 49 of Set 4 | pontianak
# Processing Record 50 of Set 4 | the pas
# Processing Record 1 of Set 5 | chimore
# Processing Record 2 of Set 5 | joshimath
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | biak
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | balaguer
# Processing Record 8 of Set 5 | san patricio
# Processing Record 9 of Set 5 | teahupoo
# Processing Record 10 of Set 5 | shimoda
# Processing Record 11 of Set 5 | norwich
# Processing Record 12 of Set 5 | tasiilaq
# Processing Record 13 of Set 5 | kailua
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | hofn
# Processing Record 16 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | mount pleasant
# Processing Record 19 of Set 5 | havre-saint-pierre
# Processing Record 20 of Set 5 | neftekamsk
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | charlestown
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | yicheng
# Processing Record 27 of Set 5 | la orilla
# Processing Record 28 of Set 5 | mushie
# Processing Record 29 of Set 5 | igrim
# Processing Record 30 of Set 5 | slawno
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | maniitsoq
# Processing Record 33 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 5 | dicabisagan
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | huajuapan
# City not found. Skipping...
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | bara
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | avarua
# Processing Record 42 of Set 5 | kahului
# Processing Record 43 of Set 5 | rancho palos verdes
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | kijang
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | henzada
# City not found. Skipping...
# Processing Record 48 of Set 5 | buala
# Processing Record 49 of Set 5 | pierre
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | lasa
# Processing Record 3 of Set 6 | shingu
# Processing Record 4 of Set 6 | dudinka
# Processing Record 5 of Set 6 | shizilu
# Processing Record 6 of Set 6 | lompoc
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | kakonko
# Processing Record 10 of Set 6 | ribeira grande
# Processing Record 11 of Set 6 | victor harbor
# Processing Record 12 of Set 6 | yumen
# Processing Record 13 of Set 6 | turukhansk
# Processing Record 14 of Set 6 | buta
# Processing Record 15 of Set 6 | salinopolis
# Processing Record 16 of Set 6 | zelenogorsk
# Processing Record 17 of Set 6 | viedma
# Processing Record 18 of Set 6 | udachnyy
# Processing Record 19 of Set 6 | road town
# Processing Record 20 of Set 6 | atambua
# Processing Record 21 of Set 6 | sadzhavka
# Processing Record 22 of Set 6 | namatanai
# Processing Record 23 of Set 6 | coquimbo
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | svetlogorsk
# Processing Record 26 of Set 6 | severo-kurilsk
# Processing Record 27 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 6 | puerto escondido
# Processing Record 29 of Set 6 | honiara
# Processing Record 30 of Set 6 | marawi
# Processing Record 31 of Set 6 | olafsvik
# Processing Record 32 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 33 of Set 6 | coracora
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | belogorsk
# Processing Record 36 of Set 6 | vostok
# Processing Record 37 of Set 6 | timra
# Processing Record 38 of Set 6 | salym
# Processing Record 39 of Set 6 | nagar karnul
# Processing Record 40 of Set 6 | pimentel
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | monze
# Processing Record 43 of Set 6 | walvis bay
# Processing Record 44 of Set 6 | alnashi
# Processing Record 45 of Set 6 | istok
# Processing Record 46 of Set 6 | terrace
# Processing Record 47 of Set 6 | arica
# Processing Record 48 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | san cosme y damian
# Processing Record 1 of Set 7 | sao domingos do prata
# Processing Record 2 of Set 7 | den helder
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | leningradskiy
# Processing Record 5 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 7 | goundam
# Processing Record 7 of Set 7 | taltal
# Processing Record 8 of Set 7 | goderich
# Processing Record 9 of Set 7 | trogir
# Processing Record 10 of Set 7 | shostka
# Processing Record 11 of Set 7 | kulhudhuffushi
# Processing Record 12 of Set 7 | qasigiannguit
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | roma
# Processing Record 16 of Set 7 | trelew
# Processing Record 17 of Set 7 | mehamn
# Processing Record 18 of Set 7 | alekseyevsk
# Processing Record 19 of Set 7 | olimpia
# Processing Record 20 of Set 7 | tazovskiy
# Processing Record 21 of Set 7 | acarau
# Processing Record 22 of Set 7 | bay roberts
# Processing Record 23 of Set 7 | malakal
# Processing Record 24 of Set 7 | san pedro
# Processing Record 25 of Set 7 | vila franca do campo
# Processing Record 26 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 7 | collie
# Processing Record 28 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 7 | hovd
# Processing Record 30 of Set 7 | bairiki
# Processing Record 31 of Set 7 | san juan
# Processing Record 32 of Set 7 | arlit
# Processing Record 33 of Set 7 | te anau
# Processing Record 34 of Set 7 | glace bay
# Processing Record 35 of Set 7 | geraldton
# Processing Record 36 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 7 | nhulunbuy
# Processing Record 38 of Set 7 | great falls
# Processing Record 39 of Set 7 | padang
# Processing Record 40 of Set 7 | ilheus
# Processing Record 41 of Set 7 | hendersonville
# Processing Record 42 of Set 7 | sinnamary
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | douentza
# Processing Record 45 of Set 7 | sisimiut
# Processing Record 46 of Set 7 | guerrero negro
# Processing Record 47 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 7 | muros
# Processing Record 49 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 7 | chicama
# Processing Record 1 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | faya
# Processing Record 3 of Set 8 | rindal
# Processing Record 4 of Set 8 | nishihara
# Processing Record 5 of Set 8 | bilma
# Processing Record 6 of Set 8 | mana
# Processing Record 7 of Set 8 | ardatov
# Processing Record 8 of Set 8 | wawa
# Processing Record 9 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 8 | sao jose de piranhas
# Processing Record 11 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 8 | rock sound
# Processing Record 13 of Set 8 | tari
# Processing Record 14 of Set 8 | tikrit
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | masallatah
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | carnot
# Processing Record 19 of Set 8 | miraflores
# Processing Record 20 of Set 8 | omaruru
# Processing Record 21 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 8 | beinamar
# Processing Record 23 of Set 8 | prabumulih
# Processing Record 24 of Set 8 | dapaong
# Processing Record 25 of Set 8 | coihueco
# Processing Record 26 of Set 8 | narsaq
# Processing Record 27 of Set 8 | mae sai
# Processing Record 28 of Set 8 | calamar
# Processing Record 29 of Set 8 | salalah
# Processing Record 30 of Set 8 | oltenita
# Processing Record 31 of Set 8 | alyangula
# Processing Record 32 of Set 8 | bereda
# Processing Record 33 of Set 8 | port hardy
# Processing Record 34 of Set 8 | bengkulu
# Processing Record 35 of Set 8 | juegang
# Processing Record 36 of Set 8 | flagstaff
# Processing Record 37 of Set 8 | denham springs
# Processing Record 38 of Set 8 | muyezerskiy
# Processing Record 39 of Set 8 | madera
# Processing Record 40 of Set 8 | vung tau
# Processing Record 41 of Set 8 | hammerfest
# Processing Record 42 of Set 8 | araouane
# Processing Record 43 of Set 8 | altay
# Processing Record 44 of Set 8 | marolambo
# Processing Record 45 of Set 8 | jumla
# Processing Record 46 of Set 8 | spirovo
# Processing Record 47 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 8 | laguna
# Processing Record 49 of Set 8 | saint-ambroise
# Processing Record 50 of Set 8 | bubaque
# Processing Record 1 of Set 9 | katobu
# Processing Record 2 of Set 9 | pafos
# Processing Record 3 of Set 9 | wuzhou
# Processing Record 4 of Set 9 | sangar
# Processing Record 5 of Set 9 | kananga
# Processing Record 6 of Set 9 | lamont
# Processing Record 7 of Set 9 | anzio
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | maceio
# Processing Record 10 of Set 9 | abu dhabi
# Processing Record 11 of Set 9 | kayerkan
# Processing Record 12 of Set 9 | caravelas
# Processing Record 13 of Set 9 | haines junction
# Processing Record 14 of Set 9 | chabahar
# Processing Record 15 of Set 9 | sao paulo de olivenca
# Processing Record 16 of Set 9 | maloy
# Processing Record 17 of Set 9 | yasothon
# Processing Record 18 of Set 9 | iringa
# Processing Record 19 of Set 9 | point pedro
# Processing Record 20 of Set 9 | worland
# Processing Record 21 of Set 9 | palmer
# Processing Record 22 of Set 9 | inuvik
# Processing Record 23 of Set 9 | corsicana
# Processing Record 24 of Set 9 | bukachacha
# Processing Record 25 of Set 9 | concepcion del oro
# Processing Record 26 of Set 9 | cotia
# Processing Record 27 of Set 9 | imeni poliny osipenko
# Processing Record 28 of Set 9 | homer
# Processing Record 29 of Set 9 | chimbote
# Processing Record 30 of Set 9 | freeport
# Processing Record 31 of Set 9 | sesheke
# Processing Record 32 of Set 9 | boulder city
# Processing Record 33 of Set 9 | teluk nibung
# Processing Record 34 of Set 9 | nyurba
# Processing Record 35 of Set 9 | kandrian
# Processing Record 36 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | risod
# Processing Record 38 of Set 9 | portobelo
# Processing Record 39 of Set 9 | nemuro
# Processing Record 40 of Set 9 | maun
# Processing Record 41 of Set 9 | cherskiy
# Processing Record 42 of Set 9 | nsanje
# Processing Record 43 of Set 9 | bajos de haina
# Processing Record 44 of Set 9 | san rafael
# Processing Record 45 of Set 9 | bima
# Processing Record 46 of Set 9 | matara
# Processing Record 47 of Set 9 | manga
# Processing Record 48 of Set 9 | shenjiamen
# Processing Record 49 of Set 9 | macapa
# Processing Record 50 of Set 9 | santa luzia
# Processing Record 1 of Set 10 | erie
# Processing Record 2 of Set 10 | sistranda
# Processing Record 3 of Set 10 | kolodeznyy
# Processing Record 4 of Set 10 | paamiut
# Processing Record 5 of Set 10 | finschhafen
# Processing Record 6 of Set 10 | kudahuvadhoo
# Processing Record 7 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 10 | willowmore
# Processing Record 9 of Set 10 | shizunai
# Processing Record 10 of Set 10 | saint-francois
# Processing Record 11 of Set 10 | patan
# Processing Record 12 of Set 10 | uige
# Processing Record 13 of Set 10 | epe
# Processing Record 14 of Set 10 | bantou
# Processing Record 15 of Set 10 | yar-sale
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | clyde river
# Processing Record 18 of Set 10 | ucluelet
# Processing Record 19 of Set 10 | roebourne
# Processing Record 20 of Set 10 | lagoa
# Processing Record 21 of Set 10 | harper
# Processing Record 22 of Set 10 | celestun
# Processing Record 23 of Set 10 | barra
# Processing Record 24 of Set 10 | vestmannaeyjar
# Processing Record 25 of Set 10 | taveta
# Processing Record 26 of Set 10 | coahuayana
# Processing Record 27 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 10 | okahandja
# Processing Record 29 of Set 10 | oppdal
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | ust-nera
# Processing Record 32 of Set 10 | sorkjosen
# Processing Record 33 of Set 10 | rabo de peixe
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | caucaia
# Processing Record 36 of Set 10 | riyadh
# Processing Record 37 of Set 10 | marsh harbour
# Processing Record 38 of Set 10 | simao
# Processing Record 39 of Set 10 | sept-iles
# Processing Record 40 of Set 10 | port macquarie
# Processing Record 41 of Set 10 | newport
# Processing Record 42 of Set 10 | cooma
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | lashio
# Processing Record 45 of Set 10 | eureka
# Processing Record 46 of Set 10 | fairbanks
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 10 | indiaroba
# Processing Record 50 of Set 10 | blagoyevo
# Processing Record 1 of Set 11 | douglas
# Processing Record 2 of Set 11 | payo
# Processing Record 3 of Set 11 | huilong
# Processing Record 4 of Set 11 | melilla
# Processing Record 5 of Set 11 | biloela
# Processing Record 6 of Set 11 | lugovoy
# Processing Record 7 of Set 11 | tual
# Processing Record 8 of Set 11 | krasnyy yar
# Processing Record 9 of Set 11 | kamiiso
# Processing Record 10 of Set 11 | bonthe
# Processing Record 11 of Set 11 | rivadavia
# Processing Record 12 of Set 11 | gondar
# Processing Record 13 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 11 | abu samrah
# Processing Record 15 of Set 11 | almora
# Processing Record 16 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 11 | naze
# Processing Record 18 of Set 11 | dunedin
# Processing Record 19 of Set 11 | victoria
# Processing Record 20 of Set 11 | almenevo
# City not found. Skipping...
# Processing Record 21 of Set 11 | vestmanna
# Processing Record 22 of Set 11 | barao de melgaco
# Processing Record 23 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 24 of Set 11 | sabang
# Processing Record 25 of Set 11 | springbok
# Processing Record 26 of Set 11 | makakilo city
# Processing Record 27 of Set 11 | turka
# Processing Record 28 of Set 11 | akyab
# Processing Record 29 of Set 11 | virginia beach
# Processing Record 30 of Set 11 | lianran
# Processing Record 31 of Set 11 | korla
# Processing Record 32 of Set 11 | lidkoping
# Processing Record 33 of Set 11 | sao caetano de odivelas
# Processing Record 34 of Set 11 | yuzhno-kurilsk
# Processing Record 35 of Set 11 | oranjemund
# Processing Record 36 of Set 11 | wanning
# Processing Record 37 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 38 of Set 11 | cauquenes
# Processing Record 39 of Set 11 | henties bay
# Processing Record 40 of Set 11 | broken hill
# Processing Record 41 of Set 11 | murray bridge
# Processing Record 42 of Set 11 | ballina
# Processing Record 43 of Set 11 | kamaishi
# Processing Record 44 of Set 11 | nipawin
# Processing Record 45 of Set 11 | pavlikeni
# Processing Record 46 of Set 11 | jardim
# Processing Record 47 of Set 11 | boende
# Processing Record 48 of Set 11 | kunming
# Processing Record 49 of Set 11 | waipawa
# Processing Record 50 of Set 11 | port blair
# Processing Record 1 of Set 12 | laohekou
# Processing Record 2 of Set 12 | general roca
# Processing Record 3 of Set 12 | lingao
# Processing Record 4 of Set 12 | bondo
# Processing Record 5 of Set 12 | verkhniye kigi
# Processing Record 6 of Set 12 | san borja
# Processing Record 7 of Set 12 | port augusta
# Processing Record 8 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 12 | gotsu
# Processing Record 10 of Set 12 | camacha
# Processing Record 11 of Set 12 | pingzhuang
# Processing Record 12 of Set 12 | vila velha
# Processing Record 13 of Set 12 | kelso
# Processing Record 14 of Set 12 | minot
# Processing Record 15 of Set 12 | strezhevoy
# Processing Record 16 of Set 12 | muret
# Processing Record 17 of Set 12 | quesnel
# Processing Record 18 of Set 12 | kalat
# Processing Record 19 of Set 12 | biltine
# Processing Record 20 of Set 12 | linfen
# Processing Record 21 of Set 12 | anamur
# Processing Record 22 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 12 | rawlins
# Processing Record 24 of Set 12 | kenai
# Processing Record 25 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 26 of Set 12 | tambacounda
# Processing Record 27 of Set 12 | tilichiki
# Processing Record 28 of Set 12 | kalangala
# Processing Record 29 of Set 12 | westport
# Processing Record 30 of Set 12 | kasongo-lunda
# Processing Record 31 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 32 of Set 12 | myitkyina
# Processing Record 33 of Set 12 | bandundu
# Processing Record 34 of Set 12 | upington
# Processing Record 35 of Set 12 | lubumbashi
# Processing Record 36 of Set 12 | russell
# Processing Record 37 of Set 12 | tahe
# Processing Record 38 of Set 12 | kidal
# Processing Record 39 of Set 12 | broome
# Processing Record 40 of Set 12 | preobrazheniye
# Processing Record 41 of Set 12 | pital
# Processing Record 42 of Set 12 | aleysk
# Processing Record 43 of Set 12 | hobyo
# Processing Record 44 of Set 12 | cullman
# Processing Record 45 of Set 12 | tigil
# Processing Record 46 of Set 12 | fort-shevchenko
# Processing Record 47 of Set 12 | olinda
# Processing Record 48 of Set 12 | pinhao
# Processing Record 49 of Set 12 | alvaraes
# Processing Record 50 of Set 12 | kaeo
# Processing Record 1 of Set 13 | ishigaki
# Processing Record 2 of Set 13 | inhambane
# Processing Record 3 of Set 13 | bardiyah
# Processing Record 4 of Set 13 | kloulklubed
# Processing Record 5 of Set 13 | berdigestyakh
# Processing Record 6 of Set 13 | sao joao da barra
# Processing Record 7 of Set 13 | itarema
# Processing Record 8 of Set 13 | hit
# Processing Record 9 of Set 13 | juruti
# Processing Record 10 of Set 13 | iberia
# Processing Record 11 of Set 13 | zabol
# Processing Record 12 of Set 13 | kytmanovo
# Processing Record 13 of Set 13 | la asuncion
# Processing Record 14 of Set 13 | sandwick
# Processing Record 15 of Set 13 | aloha
# Processing Record 16 of Set 13 | boueni
# Processing Record 17 of Set 13 | inta
# Processing Record 18 of Set 13 | huarmey
# Processing Record 19 of Set 13 | santo antonio do ica
# Processing Record 20 of Set 13 | sokoni
# Processing Record 21 of Set 13 | betare oya
# Processing Record 22 of Set 13 | sorland
# Processing Record 23 of Set 13 | lianyuan
# Processing Record 24 of Set 13 | chkalovskoye
# Processing Record 25 of Set 13 | merauke
# Processing Record 26 of Set 13 | vama buzaului
# City not found. Skipping...
# Processing Record 27 of Set 13 | lorengau
# Processing Record 28 of Set 13 | vuktyl
# Processing Record 29 of Set 13 | birin
# Processing Record 30 of Set 13 | antofagasta
# Processing Record 31 of Set 13 | gravdal
# Processing Record 32 of Set 13 | ulladulla
# Processing Record 33 of Set 13 | port shepstone
# Processing Record 34 of Set 13 | adjumani
# Processing Record 35 of Set 13 | carutapera
# Processing Record 36 of Set 13 | zhangjiakou
# Processing Record 37 of Set 13 | bada
# Processing Record 38 of Set 13 | mount isa
# Processing Record 39 of Set 13 | pacific grove
# Processing Record 40 of Set 13 | sur
# Processing Record 41 of Set 13 | conselheiro lafaiete
# Processing Record 42 of Set 13 | ranfurly
# Processing Record 43 of Set 13 | phun phin
# City not found. Skipping...
# Processing Record 44 of Set 13 | berezovyy
# Processing Record 45 of Set 13 | berlevag
# Processing Record 46 of Set 13 | kindu
# Processing Record 47 of Set 13 | kuhdasht
# Processing Record 48 of Set 13 | pishva
# Processing Record 49 of Set 13 | gambela
# Processing Record 50 of Set 13 | iranshahr
# Processing Record 1 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 14 | sarakhs
# Processing Record 3 of Set 14 | big spring
# Processing Record 4 of Set 14 | hargeysa
# Processing Record 5 of Set 14 | mizque
# Processing Record 6 of Set 14 | ilesha
# Processing Record 7 of Set 14 | hauzenberg
# Processing Record 8 of Set 14 | macusani
# Processing Record 9 of Set 14 | smoky lake
# Processing Record 10 of Set 14 | pozo colorado
# Processing Record 11 of Set 14 | ketchikan
# Processing Record 12 of Set 14 | itapaci
# Processing Record 13 of Set 14 | trapani
# Processing Record 14 of Set 14 | tahoua
# Processing Record 15 of Set 14 | noyabrsk
# Processing Record 16 of Set 14 | nouakchott
# Processing Record 17 of Set 14 | tocopilla
# Processing Record 18 of Set 14 | sheridan
# Processing Record 19 of Set 14 | gombe
# Processing Record 20 of Set 14 | knysna
# Processing Record 21 of Set 14 | anshun
# Processing Record 22 of Set 14 | iwaki
# Processing Record 23 of Set 14 | muzhi
# Processing Record 24 of Set 14 | ninh binh
# Processing Record 25 of Set 14 | senneterre
# Processing Record 26 of Set 14 | morondava
# Processing Record 27 of Set 14 | porterville
# Processing Record 28 of Set 14 | cienfuegos
# Processing Record 29 of Set 14 | panzhihua
# Processing Record 30 of Set 14 | linjiang
# Processing Record 31 of Set 14 | yeppoon
# Processing Record 32 of Set 14 | sao mateus do maranhao
# Processing Record 33 of Set 14 | kondinskoye
# Processing Record 34 of Set 14 | aklavik
# Processing Record 35 of Set 14 | kamo
# Processing Record 36 of Set 14 | diego de almagro
# Processing Record 37 of Set 14 | marang
# Processing Record 38 of Set 14 | micheweni
# Processing Record 39 of Set 14 | leighton buzzard
# Processing Record 40 of Set 14 | york
# Processing Record 41 of Set 14 | zemen
# Processing Record 42 of Set 14 | caohai
# Processing Record 43 of Set 14 | tomatlan
# Processing Record 44 of Set 14 | requena
# Processing Record 45 of Set 14 | traverse city
# Processing Record 46 of Set 14 | bosaso
# Processing Record 47 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 48 of Set 14 | krasnoyarskiy
# Processing Record 49 of Set 14 | alta floresta
# Processing Record 50 of Set 14 | orsha
# Processing Record 1 of Set 15 | sibu
# Processing Record 2 of Set 15 | cabatuan
# Processing Record 3 of Set 15 | coalcoman
# City not found. Skipping...
# Processing Record 4 of Set 15 | artigas
# Processing Record 5 of Set 15 | nuevo progreso
# Processing Record 6 of Set 15 | dobroye
# Processing Record 7 of Set 15 | kawalu
# Processing Record 8 of Set 15 | mizdah
# Processing Record 9 of Set 15 | hailar
# Processing Record 10 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 11 of Set 15 | monroe
# Processing Record 12 of Set 15 | taoudenni
# Processing Record 13 of Set 15 | volary
# Processing Record 14 of Set 15 | bonham
# Processing Record 15 of Set 15 | xichang
# Processing Record 16 of Set 15 | jawhar
# Processing Record 17 of Set 15 | kraslava
# Processing Record 18 of Set 15 | mabaruma
# Processing Record 19 of Set 15 | porbandar
# Processing Record 20 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 15 | jacareacanga
# Processing Record 22 of Set 15 | kefalos
# Processing Record 23 of Set 15 | hermiston
# Processing Record 24 of Set 15 | roald
# Processing Record 25 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 26 of Set 15 | erenhot
# Processing Record 27 of Set 15 | timizart
# Processing Record 28 of Set 15 | ngunguru
# Processing Record 29 of Set 15 | iquique
# Processing Record 30 of Set 15 | ekimchan
# Processing Record 31 of Set 15 | imeni babushkina
# Processing Record 32 of Set 15 | marietta
# Processing Record 33 of Set 15 | tabas
# Processing Record 34 of Set 15 | husavik
# Processing Record 35 of Set 15 | amapa
# Processing Record 36 of Set 15 | ubon ratchathani
# Processing Record 37 of Set 15 | luanda
# Processing Record 38 of Set 15 | wajir
# Processing Record 39 of Set 15 | hervey bay
# Processing Record 40 of Set 15 | keuruu
# Processing Record 41 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 15 | skopin
# Processing Record 43 of Set 15 | le port
# Processing Record 44 of Set 15 | la palma
# Processing Record 45 of Set 15 | tabou
# Processing Record 46 of Set 15 | zyryanka
# Processing Record 47 of Set 15 | canala
# Processing Record 48 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 15 | oksfjord
# Processing Record 50 of Set 15 | pratapgarh
# Processing Record 1 of Set 16 | wilmington
# Processing Record 2 of Set 16 | nuuk
# Processing Record 3 of Set 16 | guiberoua
# Processing Record 4 of Set 16 | ribnitz-damgarten
# Processing Record 5 of Set 16 | aykhal
# Processing Record 6 of Set 16 | itapipoca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Nanortalik      GL  60.1432  -45.2371     39.34        81          95
# 1      Kavaratti      IN  10.5669   72.6420     82.81        76           5
# 2        Mataura      NZ -46.1927  168.8643     39.36        99          35
# 3    Port Alfred      ZA -33.5906   26.8910     61.18        96         100
# 4      Raudeberg      NO  61.9875    5.1352     38.07        77          23
# 5   Punta Arenas      CL -53.1500  -70.9167     48.22        76          75
# 6    Yellowknife      CA  62.4560 -114.3525     -2.58        66         100
# 7  Manuk Mangkaw      PH   4.8000  119.8500     81.86        79          54
# 8           Hilo      US  19.7297 -155.0900     80.33        70          20
# 9        Sechura      PE  -5.5569  -80.8222     82.99        57          82
#
#    Wind Speed          Weather Description
# 0        3.96              overcast clouds
# 1        7.74                    clear sky
# 2        1.97             scattered clouds
# 3        1.01              overcast clouds
# 4        8.66                   few clouds
# 5       13.80  light intensity shower rain
# 6       11.01              overcast clouds
# 7        9.73                broken clouds
# 8        8.05                   few clouds
# 9       10.47                broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
